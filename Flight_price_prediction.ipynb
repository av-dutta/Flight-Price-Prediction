# %% [markdown]
# <a href="https://colab.research.google.com/github/av-dutta/Flight-Price-Prediction/blob/main/Flight_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_df = pd.read_excel("/content/drive/MyDrive/Capstone imarticus/Data_Train.xlsx")
test_df =  pd.read_excel("/content/drive/MyDrive/Capstone imarticus/Test_set.xlsx")

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source  ... Total_Stops Additional_Info  Price
# 0       IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897
# 1    Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662
# 2  Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882
# 3       IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218
# 4       IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302
#
# [5 rows x 11 columns]

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey  ... Total_Stops              Additional_Info
# 0        Jet Airways       6/06/2019  ...      1 stop                      No info
# 1             IndiGo      12/05/2019  ...      1 stop                      No info
# 2        Jet Airways      21/05/2019  ...      1 stop  In-flight meal not included
# 3  Multiple carriers      21/05/2019  ...      1 stop                      No info
# 4           Air Asia      24/06/2019  ...    non-stop                      No info
#
# [5 rows x 10 columns]

# %%
big_df=train_df.append(test_df,sort=False)

# %%
big_df.tail()
# Out:
#                 Airline Date_of_Journey  ... Additional_Info Price
# 2666          Air India       6/06/2019  ...         No info   NaN
# 2667             IndiGo      27/03/2019  ...         No info   NaN
# 2668        Jet Airways       6/03/2019  ...         No info   NaN
# 2669          Air India       6/03/2019  ...         No info   NaN
# 2670  Multiple carriers      15/06/2019  ...         No info   NaN
#
# [5 rows x 11 columns]

# %%
big_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# ##Feature Engineering

# %%
big_df['Date']=big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month']=big_df['Date_of_Journey'].str.split('/').str[1]
big_df['Year']=big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination  ...    Price Date Month  Year
# 0       IndiGo      24/03/2019  Banglore   New Delhi  ...   3897.0   24    03  2019
# 1    Air India       1/05/2019   Kolkata    Banglore  ...   7662.0    1    05  2019
# 2  Jet Airways       9/06/2019     Delhi      Cochin  ...  13882.0    9    06  2019
# 3       IndiGo      12/05/2019   Kolkata    Banglore  ...   6218.0   12    05  2019
# 4       IndiGo      01/03/2019  Banglore   New Delhi  ...  13302.0   01    03  2019
#
# [5 rows x 14 columns]

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
big_df['Date']=big_df['Date'].astype(int)
big_df['Month']=big_df['Month'].astype(int)
big_df['Year']=big_df['Year'].astype(int)

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# dtype: object

# %%
big_df=big_df.drop(['Date_of_Journey'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Date Month  Year
# 0       IndiGo  Banglore   New Delhi  ...   24     3  2019
# 1    Air India   Kolkata    Banglore  ...    1     5  2019
# 2  Jet Airways     Delhi      Cochin  ...    9     6  2019
# 3       IndiGo   Kolkata    Banglore  ...   12     5  2019
# 4       IndiGo  Banglore   New Delhi  ...    1     3  2019
#
# [5 rows x 13 columns]

# %%
big_df['Arrival_Time']=big_df['Arrival_Time'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Date Month  Year
# 0       IndiGo  Banglore   New Delhi  ...   24     3  2019
# 1    Air India   Kolkata    Banglore  ...    1     5  2019
# 2  Jet Airways     Delhi      Cochin  ...    9     6  2019
# 3       IndiGo   Kolkata    Banglore  ...   12     5  2019
# 4       IndiGo  Banglore   New Delhi  ...    1     3  2019
#
# [5 rows x 13 columns]

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route  ...   Price Date Month  Year
# 9039  Air India  Delhi      Cochin   NaN  ...  7480.0    6     5  2019
#
# [1 rows x 13 columns]

# %%
big_df['Total_Stops']=big_df['Total_Stops'].fillna('1 stop')

# %%
big_df['Total_Stops']=big_df['Total_Stops'].replace('non-stop','0 stop')

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Date Month  Year
# 0       IndiGo  Banglore   New Delhi  ...   24     3  2019
# 1    Air India   Kolkata    Banglore  ...    1     5  2019
# 2  Jet Airways     Delhi      Cochin  ...    9     6  2019
# 3       IndiGo   Kolkata    Banglore  ...   12     5  2019
# 4       IndiGo  Banglore   New Delhi  ...    1     3  2019
#
# [5 rows x 13 columns]

# %%
big_df['Stop'] = big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Month  Year Stop
# 0       IndiGo  Banglore   New Delhi  ...     3  2019    0
# 1    Air India   Kolkata    Banglore  ...     5  2019    2
# 2  Jet Airways     Delhi      Cochin  ...     6  2019    2
# 3       IndiGo   Kolkata    Banglore  ...     5  2019    1
# 4       IndiGo  Banglore   New Delhi  ...     3  2019    1
#
# [5 rows x 14 columns]

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int64
# Month                int64
# Year                 int64
# Stop                object
# dtype: object

# %%
big_df['Stop']=big_df['Stop'].astype(int)
big_df=big_df.drop(['Total_Stops'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Month  Year Stop
# 0       IndiGo  Banglore   New Delhi  ...     3  2019    0
# 1    Air India   Kolkata    Banglore  ...     5  2019    2
# 2  Jet Airways     Delhi      Cochin  ...     6  2019    2
# 3       IndiGo   Kolkata    Banglore  ...     5  2019    1
# 4       IndiGo  Banglore   New Delhi  ...     3  2019    1
#
# [5 rows x 13 columns]

# %%
big_df['Arrival_Hour'] = big_df['Arrival_Time'] .str.split(':').str[0]
big_df['Arrival_Minute'] = big_df['Arrival_Time'] .str.split(':').str[1]

# %%
big_df['Arrival_Hour']=big_df['Arrival_Hour'].astype(int)
big_df['Arrival_Minute']=big_df['Arrival_Minute'].astype(int)
big_df=big_df.drop(['Arrival_Time'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Stop Arrival_Hour Arrival_Minute
# 0       IndiGo  Banglore   New Delhi  ...    0            1             10
# 1    Air India   Kolkata    Banglore  ...    2           13             15
# 2  Jet Airways     Delhi      Cochin  ...    2            4             25
# 3       IndiGo   Kolkata    Banglore  ...    1           23             30
# 4       IndiGo  Banglore   New Delhi  ...    1           21             35
#
# [5 rows x 14 columns]

# %%
big_df['Departure_Hour'] = big_df['Dep_Time'] .str.split(':').str[0]
big_df['Departure_Minute'] = big_df['Dep_Time'] .str.split(':').str[1]

# %%
big_df['Departure_Hour']=big_df['Departure_Hour'].astype(int)
big_df['Departure_Minute']=big_df['Departure_Minute'].astype(int)
big_df=big_df.drop(['Dep_Time'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source  ... Departure_Hour Departure_Minute
# 0       IndiGo  Banglore  ...             22               20
# 1    Air India   Kolkata  ...              5               50
# 2  Jet Airways     Delhi  ...              9               25
# 3       IndiGo   Kolkata  ...             18                5
# 4       IndiGo  Banglore  ...             16               50
#
# [5 rows x 15 columns]

# %%
big_df['Route_1']=big_df['Route'].str.split('→ ').str[0]
big_df['Route_2']=big_df['Route'].str.split('→ ').str[1]
big_df['Route_3']=big_df['Route'].str.split('→ ').str[2]
big_df['Route_4']=big_df['Route'].str.split('→ ').str[3]
big_df['Route_5']=big_df['Route'].str.split('→ ').str[4]

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Route_3 Route_4 Route_5
# 0       IndiGo  Banglore   New Delhi  ...     NaN     NaN     NaN
# 1    Air India   Kolkata    Banglore  ...    BBI      BLR     NaN
# 2  Jet Airways     Delhi      Cochin  ...    BOM      COK     NaN
# 3       IndiGo   Kolkata    Banglore  ...     BLR     NaN     NaN
# 4       IndiGo  Banglore   New Delhi  ...     DEL     NaN     NaN
#
# [5 rows x 20 columns]

# %%
big_df['Price'].fillna((big_df['Price'].mean()),inplace=True)

# %%
big_df['Route_1'].fillna("None",inplace=True)
big_df['Route_2'].fillna("None",inplace=True)
big_df['Route_3'].fillna("None",inplace=True)
big_df['Route_4'].fillna("None",inplace=True)
big_df['Route_5'].fillna("None",inplace=True)

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Route_3 Route_4 Route_5
# 0       IndiGo  Banglore   New Delhi  ...    None    None    None
# 1    Air India   Kolkata    Banglore  ...    BBI      BLR    None
# 2  Jet Airways     Delhi      Cochin  ...    BOM      COK    None
# 3       IndiGo   Kolkata    Banglore  ...     BLR    None    None
# 4       IndiGo  Banglore   New Delhi  ...     DEL    None    None
#
# [5 rows x 20 columns]

# %%
big_df=big_df.drop(['Route'],axis=1)
big_df=big_df.drop(['Duration'],axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination  ... Route_3  Route_4  Route_5
# 0       IndiGo  Banglore   New Delhi  ...    None     None     None
# 1    Air India   Kolkata    Banglore  ...    BBI       BLR     None
# 2  Jet Airways     Delhi      Cochin  ...    BOM       COK     None
# 3       IndiGo   Kolkata    Banglore  ...     BLR     None     None
# 4       IndiGo  Banglore   New Delhi  ...     DEL     None     None
#
# [5 rows x 18 columns]

# %%
big_df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# Year                0
# Stop                0
# Arrival_Hour        0
# Arrival_Minute      0
# Departure_Hour      0
# Departure_Minute    0
# Route_1             0
# Route_2             0
# Route_3             0
# Route_4             0
# Route_5             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
big_df["Airline"]=encoder.fit_transform(big_df['Airline'])
big_df["Source"]=encoder.fit_transform(big_df['Source'])
big_df["Destination"]=encoder.fit_transform(big_df['Destination'])
big_df["Additional_Info"]=encoder.fit_transform(big_df['Additional_Info'])
big_df["Route_1"]=encoder.fit_transform(big_df['Route_1'])
big_df["Route_2"]=encoder.fit_transform(big_df['Route_2'])
big_df["Route_3"]=encoder.fit_transform(big_df['Route_3'])
big_df["Route_4"]=encoder.fit_transform(big_df['Route_4'])
big_df["Route_5"]=encoder.fit_transform(big_df['Route_5'])

# %%
big_df.head()
# Out:
#    Airline  Source  Destination  ...  Route_3  Route_4  Route_5
# 0        3       0            5  ...       24       12        4
# 1        1       3            0  ...        1        3        4
# 2        4       2            1  ...        4        5        4
# 3        3       3            0  ...        3       12        4
# 4        3       0            5  ...        8       12        4
#
# [5 rows x 18 columns]

# %% [markdown]
# ##Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
df_train=big_df[0:10683]
df_test=big_df[10683:]

# %%
X=df_train.drop(['Price'],axis=1)
y=df_train.Price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

# %%
model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
selected_features=X_train.columns[(model.get_support())]

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stop', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
X_train=X_train.drop(['Year'],axis=1)

# %%
X_test=X_test.drop(['Year'],axis=1)

# %% [markdown]
# ##RandomForestRegressor

# %%
from sklearn.model_selection import RandomizedSearchCV
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 50 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 50, cv = 5, verbose=2, random_state=34)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=700; total time=   3.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=700; total time=   3.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=700; total time=   3.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=700; total time=   3.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=700; total time=   3.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  11.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  11.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  11.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  11.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=1200; total time=  11.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   8.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   8.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   8.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   8.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=700; total time=   8.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   1.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  16.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  16.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  16.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  16.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  16.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=100; total time=   0.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.3s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   8.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   8.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   8.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   8.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   8.8s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   7.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   8.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   8.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   8.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=900; total time=   8.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=600; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=600; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=600; total time=   2.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=600; total time=   2.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=600; total time=   2.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   7.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   7.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   7.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1200; total time=   7.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   3.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   3.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   3.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   3.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   3.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   4.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   4.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   4.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   4.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   4.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   4.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   4.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   1.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=500; total time=   2.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   3.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=  12.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=  12.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  10.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  10.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  10.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  10.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  10.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=   5.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=   5.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=   5.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=   5.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=800; total time=   5.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=400; total time=   1.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  14.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  14.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  14.8s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  14.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  14.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1100; total time=  12.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1100; total time=  12.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  13.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  13.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  13.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  13.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  13.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   2.0s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   5.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=   5.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=   5.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=   5.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=   5.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500; total time=   5.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=300; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=600; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=600; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=600; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=600; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=600; total time=   1.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   4.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1100; total time=  11.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1100; total time=  12.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1100; total time=  12.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1100; total time=  12.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1100; total time=  11.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   2.2s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=34, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
y_pred=rf_random.predict(X_test)

# %%
sns.distplot(y_test-y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,y_pred)
